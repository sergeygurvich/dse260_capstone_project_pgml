# %% [markdown]
# # Homogeneous_Grass_1155 Dataset EDA
# ## DSE-260 Group2
#
# ### Imports

# %%
import bp3d
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
c = bp3d.Client(url='https://burnpro3d.sdsc.edu/api')
ens = c.load_ensemble('uniform-pgml-success.bp3d.json')
out = ens.output()
# Out:
# replacing ignite.dat with 99eb7e21-df90-4c56-9fa5-a3dfcb01e1f7
# replacing ignite.dat with 64086a8d-347f-44e2-8231-2c3fe6e7019e
# replacing ignite.dat with 33b4cac3-66d6-4ecb-94a8-8d8dd07a8fbc
# replacing ignite.dat with ab9b2500-b4c0-4b6b-adf0-6932263c41da
# replacing ignite.dat with 0508604a-6d5b-4acf-a05f-4fb7e7acf74a
# Save ensemble to replace ignition file contents with new ids.

# %% [markdown]
# ### Explore Data

# %%
# lets look at run # 1 [0]:
run = run

# %%
run.tree()
# Out:
# /
#  ├── fire-energy_to_atmos (601, 1, 300, 300) float16
#  ├── fuels-dens (601, 1, 300, 300) float16
#  ├── fuels-moist (601, 1, 300, 300) float16
#  ├── surfEnergy (600, 1, 300, 300) float16
#  ├── topography (300, 300) float16
#  ├── windu (601, 1, 300, 300) float16
#  ├── windv (601, 1, 300, 300) float16
#  └── windw (601, 1, 300, 300) float16

# %% [markdown]
# #### We can see that the simulation run contains 8 arrays of different data:
# - Fire Energy to Atmosphere
# - Fuel Density
# - Fuel Moisture
# - Surf Energy
# - Topography
# - 3 directions of the Wind Speed

# %% [markdown]
# ### Explore the Topography feature

# %%
feature = 'topography'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.0
# STD:  0.0
# Min:  0.0
# Max:  0.0

# %% [markdown]
# ### Explore the Wind Direction feature

# %%
feature = 'windu'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.35028521230080295
# STD:  0.9645103363294655
# Min:  -54.28125
# Max:  49.125

# %%
feature = 'windv'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.29432040846972063
# STD:  0.8461594153894615
# Min:  -53.59375
# Max:  52.6875

# %%
feature = 'windw'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.0006018594263816061
# STD:  0.28886289522705155
# Min:  -16.5
# Max:  26.53125

# %%
windu_mean_over_time = [ feature_data[x,0,:,:].mean() for x in range(601)]
time = [x for x in range(601)]
plt.plot(time, windu_mean_over_time)
plt.title('Average wind-w at over time')
plt.xlabel('time steps')
plt.ylabel('mean wind speed m/s')
# Out:
# Text(0, 0.5, 'mean wind speed m/s')

# %% [markdown]
# ### Explore the Fuel Moisture feature

# %%
feature = 'fuels-moist'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.04536255234205628
# STD:  0.01413877985631988
# Min:  0.0
# Max:  0.04998779296875

# %%
fuels_moist_over_time = [ feature_data[x,0,:,:].mean() for x in range(601)]
time = [x for x in range(601)]
plt.plot(time, fuels_moist_over_time)
plt.title('Fuels Moisture over Time')
plt.xlabel('time steps')
plt.ylabel('Fuels Moist')
# Out:
# Text(0, 0.5, 'Fuels Moist')

# %% [markdown]
# ### Explore the Fire Energy to Atmosphere

# %%
feature = 'fire-energy_to_atmos'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  1.6024772323904604
# STD:  18.81067752369245
# Min:  0.0
# Max:  3424.0

# %%
energy_to_atmos_over_time = [ feature_data[x,0,:,:].mean() for x in range(601)]
time = [x for x in range(601)]
plt.plot(time, energy_to_atmos_over_time)
plt.title('Fire Energy to Atmosphere over Time')
plt.xlabel('time steps')
plt.ylabel('Fire Energy')
# Out:
# Text(0, 0.5, 'Fire Energy')

# %% [markdown]
# ### Explore the Surface Energy Feature

# %%
feature = 'surfEnergy'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  2.095781462626987
# STD:  33.674950297762685
# Min:  0.0
# Max:  3190.0

# %%
surf_energy_over_time = [ feature_data[x,0,:,:].mean() for x in range(600)]
time = [x for x in range(600)]
plt.plot(time, surf_energy_over_time)
plt.title('Surf Energy over Time')
plt.xlabel('time steps')
plt.ylabel('Surf Energy')
# Out:
# Text(0, 0.5, 'Surf Energy')

# %% [markdown]
# ### Explore the Fuel Density Feature

# %%
feature = 'fuels-dens'
feature_data = np.array(run[feature], dtype=np.dtype('f8'))
print('Mean: ', feature_data.mean())
print('STD: ', feature_data.std())
print('Min: ', feature_data.min())
print('Max: ', feature_data.max())
# Out:
# Mean:  0.6404692534560791
# STD:  0.19299312096433482
# Min:  0.0
# Max:  0.7001953125

# %%
fuels_dens_over_time = [ feature_data[x,0,:,:].mean() for x in range(600)]
time = [x for x in range(600)]
plt.plot(time, fuels_dens_over_time)
plt.title('Fuel Density over Time')
plt.xlabel('time steps')
plt.ylabel('Fuel Density kg/m^3')
# Out:
# Text(0, 0.5, 'Fuel Density kg/m^3')

# %% [markdown]
# #### Plot bulk density changes / fire spread over time on 2D surface

# %%
fig, axs = plt.subplots(3, 4,figsize=(10,10))
times=[0,1,10,50,100,200,250,300,350,400,500,600]

for i, ax in enumerate(axs.flatten()):
    ax.set_title(f"Time step: t={times[i]}")
    ax.imshow(feature_data[times[i],0,:,:],cmap='rainbow',origin="lower")
fig.tight_layout()
